# %%
import numpy as np
import matplotlib.pyplot as plt
from mne.io import RawArray
from mne import create_info

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
data = np.load('resampled.npy')

# %%
info_m = create_info(data.shape[0], 200, 'misc')

# %%
raw_m = RawArray(data, info_m)
# Out:
# Creating RawArray with float64 data, n_channels=124, n_times=2359235
#     Range : 0 ... 2359234 =      0.000 ... 11796.170 secs
# Ready.

# %%
fig = raw_m.plot(n_channels=20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bad_channels = np.array([33,54,67,71,93,113])

# %%
info = create_info(data[np.array([i for i in np.arange(0,124) if i not in bad_channels])].shape[0], 200, 'misc')

# %%
raw = RawArray(data[np.array([i for i in np.arange(0,124) if i not in bad_channels])],info)
# Out:
# Creating RawArray with float64 data, n_channels=118, n_times=2359235
#     Range : 0 ... 2359234 =      0.000 ... 11796.170 secs
# Ready.

# %%
fig = raw.plot(n_channels=20)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_g = data[np.array([i for i in np.arange(0,124) if i not in bad_channels])]

# %%
data_mean = np.mean(data_g, axis=0)

# %%
np.arange(0,51,50)
# Out:
# array([ 0, 50])

# %%
matrix = []
for slide in np.arange(-50,51,10):
    matrix.append(np.dot(data_g, np.concatenate((data_mean[slide:], data_mean[:slide]))))

# %%
plt.imshow(matrix, aspect='auto')
plt.colorbar()

# %%
numx = 10
numy = 6
fig, axs = plt.subplots(numx, numy, figsize = (15,10))
for i in range(numx):
    for j in range(numy):
        axs[i,j].scatter(data[2*(i+numx*j),::1000], data[2*(i+numx*j)+1,::1000], s=2)

# %%
numx = 20
numy = 6
fig, axs = plt.subplots(numx, numy, figsize = (15,20))
for i in range(numx):
    for j in range(numy):
        axs[i,j].scatter(data[93,::1000], data[i+numx*j,::1000], s=2)

# %%
numx = 20
numy = 6
fig, axs = plt.subplots(numx, numy, figsize = (15,20))
for i in range(numx):
    for j in range(numy):
        axs[i,j].scatter(data[59,::1000], data[i+numx*j,::1000], s=2)

# %%
plt.scatter(data[59,::5], data[10,::5], s=1)

# %%
plt.scatter(data[59,::5], data[50,::5], s=2)

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(data[59,::50], data[10,::50], data[50,::50], s=2);
ax.view_init(30, 60)
